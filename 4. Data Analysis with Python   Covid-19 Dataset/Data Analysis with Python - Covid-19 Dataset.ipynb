# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Biplob\Desktop\Python for Machine Learning and Data Science\All Projects - Data Analytics\4. Data Analysis with Python   Covid-19 Dataset\4. covid_19_data.csv')

# %%
data
# Out:
#           Date                     State                  Region  Confirmed  \
# 0    4/29/2020                       NaN             Afghanistan       1939
# 1    4/29/2020                       NaN                 Albania        766
# 2    4/29/2020                       NaN                 Algeria       3848
# 3    4/29/2020                       NaN                 Andorra        743
# 4    4/29/2020                       NaN                  Angola         27
# 5    4/29/2020                       NaN     Antigua and Barbuda         24
# 6    4/29/2020                       NaN               Argentina       4285
# 7    4/29/2020                       NaN                 Armenia       1932
# 8    4/29/2020                       NaN                 Austria      15402
# 9    4/29/2020                       NaN              Azerbaijan       1766
# 10   4/29/2020                       NaN                 Bahamas         80
# ...

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
data.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum().head(10)
# Out:
#                      Confirmed  Recovered
# Region
# Afghanistan               1939        252
# Albania                    766        455
# Algeria                   3848       1702
# Andorra                    743        423
# Angola                      27          7
# Antigua and Barbuda         24         11
# Argentina                 4285       1192
# Armenia                   1932        900
# Australia                 6752       5715
# Austria                  15402      12779

# %% [markdown]
# # Q. 2) Remove all the records where Confirmed Cases is Less Than 10.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
#data[~(data.Confirmed < 10)].head(10)
data = data[~(data.Confirmed < 10)]   #To remove the records satisfying a particular condition.

# %%
data
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %% [markdown]
# # Q. 3) In which Region, maximum number of Confirmed cases were recorded ?

# %%
data.head(3)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q. 4) In which Region, minimum number of Deaths cases were recorded ?

# %%
data.head(4)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(30)
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %% [markdown]
# # Q. 5) How many Confirmed, Deaths & Recovered cases were reported from Bangladesh till 29 April 2020 ?

# %%
data.head(4)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423

# %%
data[data.Region == 'Bangladesh']
# Out:
#          Date State      Region  Confirmed  Deaths  Recovered
# 12  4/29/2020   NaN  Bangladesh       7103     163        150

# %% [markdown]
# # Q.6-A) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
data.head(4)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423

# %%
data.sort_values(by = ['Confirmed'], ascending = True).head(20)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 305  4/29/2020                             Tibet         Mainland China
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 272  4/29/2020             Northwest Territories                 Canada
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# 194  4/29/2020            British Virgin Islands                     UK
# 177  4/29/2020                               NaN         Western Sahara
# ...

# %% [markdown]
# # Q.6-A) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
data.sort_values(by = ['Recovered'], ascending = False).head(20)
# Out:
#           Date      State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020        NaN           Spain     236899   24275     132929
# 285  4/29/2020  Recovered              US          0       0     120720
# 61   4/29/2020        NaN         Germany     161539    6467     120400
# 76   4/29/2020        NaN            Iran      93657    5957      73791
# 80   4/29/2020        NaN           Italy     203591   27682      71252
# 229  4/29/2020      Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020        NaN          France     165093   24087      48228
# 167  4/29/2020        NaN          Turkey     117589    3081      44040
# 22   4/29/2020        NaN          Brazil      79685    5513      34132
# 158  4/29/2020        NaN     Switzerland      29407    1716      22600
# 284  4/29/2020  Recovered          Canada          0       0      20327
# 78   4/29/2020        NaN         Ireland      20253    1190      13386
# ...

# %% [markdown]
# # Some Matplotlib Data Visualization

# %%
#In which Region, minimum number of Deaths cases were recorded ?
death_cases = data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(30)

# %%
# bar chart
death_cases.plot(kind='bar')

# display plot
plt.show()
